# %%
import pandas as pd
import numpy as np

# %%
nyc=pd.read_csv('/home/labsuser/Adi/311_Service_Requests_from_2010_to_Present.csv',low_memory=False)

# %%
import os
os.getcwd()
# Out:
# '/home/labsuser/Adi'

# %%
nyc.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
nyc.shape
# Out:
# (364558, 53)

# %%
# object.method()
# object.attribute

# %%
# data types of the col

nyc.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Description             object
# ...

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364558 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      364558 non-null  int64
#  1   Created Date                    364558 non-null  object
#  2   Closed Date                     362177 non-null  object
#  3   Agency                          364558 non-null  object
#  4   Agency Name                     364558 non-null  object
#  5   Complaint Type                  364558 non-null  object
#  6   Descriptor                      358057 non-null  object
#  7   Location Type                   364425 non-null  object
#  8   Incident Zip                    361560 non-null  float64
#  9   Incident Address                312859 non-null  object
#  10  Street Name                     312859 non-null  object
#  11  Cross Street 1                  307370 non-null  object
# ...

# %%
# missing values

nyc.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2381
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2402
# ...

# %%
# change the date format of the colums
a=nyc['Created Date'][:5]

# %%
a
# Out:
# 0    12/31/2015 11:59:45 PM
# 1    12/31/2015 11:59:44 PM
# 2    12/31/2015 11:59:29 PM
# 3    12/31/2015 11:57:46 PM
# 4    12/31/2015 11:56:58 PM
# Name: Created Date, dtype: object

# %%
a=pd.DataFrame(a)

# %%
a
# Out:
#              Created Date
# 0  12/31/2015 11:59:45 PM
# 1  12/31/2015 11:59:44 PM
# 2  12/31/2015 11:59:29 PM
# 3  12/31/2015 11:57:46 PM
# 4  12/31/2015 11:56:58 PM

# %%
pd.to_datetime(a['Created Date'],format="%m/%d/%Y %H:%M:%S %p")
# Out:
# 0   2015-12-31 11:59:45
# 1   2015-12-31 11:59:44
# 2   2015-12-31 11:59:29
# 3   2015-12-31 11:57:46
# 4   2015-12-31 11:56:58
# Name: Created Date, dtype: datetime64[ns]

# %%
#format - mm/dd/

# %%
# nyc['Created Date']=pd.to_datetime(nyc['Created Date'],format="%m/%d/%Y %H:%M:%S %p")

# %%
nyc['Created Date']=pd.to_datetime(nyc['Created Date'])

# %%
nyc['Closed Date']=pd.to_datetime(nyc['Closed Date'])

# %%
nyc['Closed Date']=pd.to_datetime(nyc['Closed Date'],format="%m/%d/%Y %H:%M:%S %p")

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364558 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      364558 non-null  int64
#  1   Created Date                    364558 non-null  datetime64[ns]
#  2   Closed Date                     362177 non-null  datetime64[ns]
#  3   Agency                          364558 non-null  object
#  4   Agency Name                     364558 non-null  object
#  5   Complaint Type                  364558 non-null  object
#  6   Descriptor                      358057 non-null  object
#  7   Location Type                   364425 non-null  object
#  8   Incident Zip                    361560 non-null  float64
#  9   Incident Address                312859 non-null  object
#  10  Street Name                     312859 non-null  object
# ...

# %%
nyc['Created Date'].dt.year
# Out:
# 0         2015
# 1         2015
# 2         2015
# 3         2015
# 4         2015
#           ...
# 364553    2015
# 364554    2015
# 364555    2015
# 364556    2015
# 364557    2015
# Name: Created Date, Length: 364558, dtype: int64

# %%
nyc['Created Date'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 364553     1
# 364554     1
# 364555     1
# 364556     1
# 364557     1
# Name: Created Date, Length: 364558, dtype: int64

# %%
nyc['Created Date'].dt.day
# Out:
# 0         31
# 1         31
# 2         31
# 3         31
# 4         31
#           ..
# 364553     1
# 364554     1
# 364555     1
# 364556     1
# 364557     1
# Name: Created Date, Length: 364558, dtype: int64

# %%
nyc['Created Date'].dt.quarter
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 364553    1
# 364554    1
# 364555    1
# 364556    1
# 364557    1
# Name: Created Date, Length: 364558, dtype: int64

# %%
nyc['resp_time']=nyc['Closed Date']-nyc['Created Date']

# %%
# nyc['resp_time_days']=nyc['resp_time']/np.timedelta64(1,'D')

# %%
nyc['resp_time_hrs']=nyc['resp_time']/np.timedelta64(1,'h')

# %%
nyc.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
nyc.head(100).to_csv('nyc100.csv')

# %%
# % of missing values

# %%
for i in nyc.columns:
    print("% of missing values for " +i +str(nyc[i].isnull().sum()/nyc.shape[0])+" %")
# Out:
# % of missing values for Unique Key0.0 %
# % of missing values for Created Date0.0 %
# % of missing values for Closed Date0.006531196682009447 %
# % of missing values for Agency0.0 %
# % of missing values for Agency Name0.0 %
# % of missing values for Complaint Type0.0 %
# % of missing values for Descriptor0.017832553393424367 %
# % of missing values for Location Type0.0003648253501500447 %
# % of missing values for Incident Zip0.008223657140976197 %
# % of missing values for Incident Address0.1418128253940388 %
# % of missing values for Street Name0.1418128253940388 %
# % of missing values for Cross Street 10.15686941446902825 %
# % of missing values for Cross Street 20.158561874927995 %
# % of missing values for Intersection Street 10.8597753992505993 %
# % of missing values for Intersection Street 20.8614431722798567 %
# % of missing values for Address Type0.008920391268330417 %
# % of missing values for City0.008220914093230707 %
# ...

# %%
# city wise complaint freq plot

# %%
nyc['City']
# Out:
# 0                 NEW YORK
# 1                  ASTORIA
# 2                    BRONX
# 3                    BRONX
# 4                 ELMHURST
#                 ...
# 364553           WOODHAVEN
# 364554               BRONX
# 364555            NEW YORK
# 364556               BRONX
# 364557    SOUTH OZONE PARK
# Name: City, Length: 364558, dtype: object

# %%
nyc.groupby('City')['Unique Key'].count()
# Out:
# City
# ARVERNE                   259
# ASTORIA                  7991
# Astoria                   906
# BAYSIDE                  1550
# BELLEROSE                 487
# BREEZY POINT               31
# BRONX                   49171
# BROOKLYN               118862
# CAMBRIA HEIGHTS           617
# CENTRAL PARK              110
# COLLEGE POINT            1544
# CORONA                   5383
# EAST ELMHURST            3558
# ELMHURST                 3438
# East Elmhurst              30
# FAR ROCKAWAY             1397
# FLORAL PARK               196
# FLUSHING                 7487
# FOREST HILLS             2122
# FRESH MEADOWS            2453
# GLEN OAKS                 361
# HOLLIS                   1231
# HOWARD BEACH             1144
# Howard Beach                1
# JACKSON HEIGHTS          2106
# JAMAICA                  8932
# KEW GARDENS              1008
# LITTLE NECK               712
# LONG ISLAND CITY         3028
# Long Island City          170
# MASPETH                  3118
# ...

# %%
nyc['City'].value_counts()
# Out:
# BROOKLYN               118862
# NEW YORK                77312
# BRONX                   49171
# STATEN ISLAND           15340
# JAMAICA                  8932
# ASTORIA                  7991
# FLUSHING                 7487
# RIDGEWOOD                6392
# CORONA                   5383
# WOODSIDE                 4357
# EAST ELMHURST            3558
# OZONE PARK               3446
# ELMHURST                 3438
# SOUTH RICHMOND HILL      3431
# MASPETH                  3118
# WOODHAVEN                3103
# LONG ISLAND CITY         3028
# SOUTH OZONE PARK         2668
# FRESH MEADOWS            2453
# RICHMOND HILL            2335
# MIDDLE VILLAGE           2291
# QUEENS VILLAGE           2251
# FOREST HILLS             2122
# JACKSON HEIGHTS          2106
# REGO PARK                1807
# BAYSIDE                  1550
# COLLEGE POINT            1544
# FAR ROCKAWAY             1397
# WHITESTONE               1369
# HOLLIS                   1231
# HOWARD BEACH             1144
# ...

# %%
import matplotlib.pyplot as plt

# %%
top_15_city=nyc['City'].value_counts()[:15]

# %%
top_15_city
# Out:
# BROOKLYN               118862
# NEW YORK                77312
# BRONX                   49171
# STATEN ISLAND           15340
# JAMAICA                  8932
# ASTORIA                  7991
# FLUSHING                 7487
# RIDGEWOOD                6392
# CORONA                   5383
# WOODSIDE                 4357
# EAST ELMHURST            3558
# OZONE PARK               3446
# ELMHURST                 3438
# SOUTH RICHMOND HILL      3431
# MASPETH                  3118
# Name: City, dtype: int64

# %%
top_15_city.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# scatter plot for brooklyn

df1=nyc[nyc['City']=='BROOKLYN']

# %%
df1.head()
# Out:
#     Unique Key        Created Date         Closed Date Agency  \
# 5     32306554 2015-12-31 23:56:30 2016-01-01 01:50:11   NYPD
# 9     32308391 2015-12-31 23:53:58 2016-01-01 01:17:40   NYPD
# 13    32305074 2015-12-31 23:47:58 2016-01-01 08:18:47   NYPD
# 17    32310273 2015-12-31 23:44:52 2016-01-01 00:36:10   NYPD
# 18    32306617 2015-12-31 23:40:59 2016-01-01 02:37:28   NYPD
#
#                         Agency Name      Complaint Type  \
# 5   New York City Police Department     Illegal Parking
# 9   New York City Police Department    Blocked Driveway
# 13  New York City Police Department     Illegal Parking
# 17  New York City Police Department  Noise - Commercial
# 18  New York City Police Department  Noise - Commercial
#
#                        Descriptor        Location Type  Incident Zip  \
# 5   Posted Parking Sign Violation      Street/Sidewalk       11215.0
# 9                       No Access      Street/Sidewalk       11219.0
# ...

# %%
plt.scatter(x=df1['Latitude'],y=df1['Longitude'])

# %%
# hexbin plot
df1.plot(kind='hexbin',x='Latitude',y='Longitude',colormap='jet',mincnt=1)
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Longitude'>

# %%
#types of complaints
nyc.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
top10_comp=nyc['Complaint Type'].value_counts()[:10]

# %%
top10_comp
# Out:
# Blocked Driveway           100881
# Illegal Parking             92679
# Noise - Street/Sidewalk     51692
# Noise - Commercial          44109
# Derelict Vehicle            21661
# Noise - Vehicle             19352
# Animal Abuse                10541
# Traffic                      5198
# Homeless Encampment          4879
# Vending                      4192
# Name: Complaint Type, dtype: int64

# %%
pd.DataFrame(top10_comp).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
top10_comp.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
city_complaint_type=nyc.groupby(['City','Complaint Type'])['Unique Key'].count().unstack()

# %%
city_complaint_type
# Out:
# Complaint Type       Animal Abuse  Blocked Driveway  Derelict Vehicle  \
# City
# ARVERNE                      46.0              50.0              32.0
# ASTORIA                     170.0            3436.0             426.0
# Astoria                       NaN             159.0              14.0
# BAYSIDE                      53.0             514.0             231.0
# BELLEROSE                    15.0             138.0             120.0
# BREEZY POINT                  2.0               3.0               3.0
# BRONX                      1971.0           17063.0            2403.0
# BROOKLYN                   3191.0           36447.0            6259.0
# CAMBRIA HEIGHTS              15.0             177.0             148.0
# CENTRAL PARK                  NaN               NaN               NaN
# COLLEGE POINT                35.0             597.0             223.0
# CORONA                      104.0            3597.0              72.0
# ...

# %%
pd.pivot_table(data=nyc,index='City',columns='Complaint Type',aggfunc='count',values='Unique Key')
# Out:
# Complaint Type       Animal Abuse  Animal in a Park  \
# City
# ARVERNE                      46.0               NaN
# ASTORIA                     170.0               NaN
# Astoria                       NaN               NaN
# BAYSIDE                      53.0               NaN
# BELLEROSE                    15.0               NaN
# BREEZY POINT                  2.0               NaN
# BRONX                      1971.0               NaN
# BROOKLYN                   3191.0               NaN
# CAMBRIA HEIGHTS              15.0               NaN
# CENTRAL PARK                  NaN               NaN
# COLLEGE POINT                35.0               NaN
# CORONA                      104.0               NaN
# EAST ELMHURST                85.0               NaN
# ELMHURST                     59.0               NaN
# East Elmhurst                 NaN               NaN
# FAR ROCKAWAY                111.0               NaN
# FLORAL PARK                   7.0               NaN
# ...

# %%
top10_comp
# Out:
# Blocked Driveway           100881
# Illegal Parking             92679
# Noise - Street/Sidewalk     51692
# Noise - Commercial          44109
# Derelict Vehicle            21661
# Noise - Vehicle             19352
# Animal Abuse                10541
# Traffic                      5198
# Homeless Encampment          4879
# Vending                      4192
# Name: Complaint Type, dtype: int64

# %%
top_15_city
# Out:
# BROOKLYN               118862
# NEW YORK                77312
# BRONX                   49171
# STATEN ISLAND           15340
# JAMAICA                  8932
# ASTORIA                  7991
# FLUSHING                 7487
# RIDGEWOOD                6392
# CORONA                   5383
# WOODSIDE                 4357
# EAST ELMHURST            3558
# OZONE PARK               3446
# ELMHURST                 3438
# SOUTH RICHMOND HILL      3431
# MASPETH                  3118
# Name: City, dtype: int64

# %%
top_15_city.index
# Out:
# Index(['BROOKLYN', 'NEW YORK', 'BRONX', 'STATEN ISLAND', 'JAMAICA', 'ASTORIA',
#        'FLUSHING', 'RIDGEWOOD', 'CORONA', 'WOODSIDE', 'EAST ELMHURST',
#        'OZONE PARK', 'ELMHURST', 'SOUTH RICHMOND HILL', 'MASPETH'],
#       dtype='object')

# %%
# extract the top 10 city from the top10 complaints
top10_comp_df=nyc[nyc['Complaint Type'].isin(top10_comp.index)]

# %%
top10_city=nyc['City'].value_counts()[:10]

# %%
# from top10 complaint types dataframe, i want the top10 city only
top10_city_comp=top10_comp_df[top10_comp_df['City'].isin(top10_city.index)]

# %%
top10_city_comp.shape
# Out:
# (293051, 55)

# %%
top10_city_comp_cnt=pd.crosstab(index=top10_city_comp['City'],columns=top10_city_comp['Complaint Type'])

# %%
top10_city_comp_cnt
# Out:
# Complaint Type  Animal Abuse  Blocked Driveway  Derelict Vehicle  \
# City
# ASTORIA                  170              3436               426
# BRONX                   1971             17063              2403
# BROOKLYN                3191             36447              6259
# CORONA                   104              3597                72
# FLUSHING                 191              3641               532
# JAMAICA                  317              3621              1133
# NEW YORK                1941              2707               695
# RIDGEWOOD                154              2162               507
# STATEN ISLAND            786              2845              2184
# WOODSIDE                 111              2038               298
#
# Complaint Type  Homeless Encampment  Illegal Parking  Noise - Commercial  \
# City
# ASTORIA                          32             1340                1653
# BRONX                           275             9889                2945
# ...

# %%
top10_city_comp_cnt.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
top10_city_comp_cnt.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='City'>

# %%
# Check if the average response time across various types of complaints is same or not

# %%
nyc.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
pd.pivot_table(data=nyc,index='Complaint Type',values='resp_time_hrs',aggfunc=np.mean)
# Out:
#                            resp_time_hrs
# Complaint Type
# Agency Issues                   5.080312
# Animal Abuse                    5.009043
# Animal in a Park              336.842778
# Bike/Roller/Skate Chronic       3.645469
# Blocked Driveway                4.509034
# Derelict Vehicle                7.044333
# Disorderly Youth                3.434375
# Drinking                        3.839250
# Graffiti                        6.465651
# Homeless Encampment             4.292051
# Illegal Fireworks               2.809301
# Illegal Parking                 4.347343
# Noise - Commercial              3.079378
# Noise - House of Worship        3.164191
# Noise - Park                    3.396127
# Noise - Street/Sidewalk         3.397582
# Noise - Vehicle                 3.489389
# Panhandling                     4.403764
# Posting Advertisement           2.023960
# Squeegee                        4.044514
# Traffic                         3.419200
# ...

# %%
# since this is only for 1 sample . we want to find if it is true for the entire population

# %%
top10_comp
# Out:
# Blocked Driveway           100881
# Illegal Parking             92679
# Noise - Street/Sidewalk     51692
# Noise - Commercial          44109
# Derelict Vehicle            21661
# Noise - Vehicle             19352
# Animal Abuse                10541
# Traffic                      5198
# Homeless Encampment          4879
# Vending                      4192
# Name: Complaint Type, dtype: int64

# %%
type1=nyc[nyc['Complaint Type']=='Blocked Driveway']['resp_time_hrs'].dropna()

# %%
type1
# Out:
# 1         1.453611
# 2         4.859444
# 7         1.813611
# 9         1.395000
# 10        7.811111
#             ...
# 364548    2.563611
# 364549    1.161389
# 364550    5.976389
# 364556    2.681389
# 364557    2.783333
# Name: resp_time_hrs, Length: 100624, dtype: float64

# %%
type2=nyc[nyc['Complaint Type']=='Illegal Parking']['resp_time_hrs'].dropna()

# %%
type3=nyc[nyc['Complaint Type']=='Noise - Street/Sidewalk']['resp_time_hrs'].dropna()

# %%
type4=nyc[nyc['Complaint Type']=='Noise - Commercial']['resp_time_hrs'].dropna()

# %%
type5=nyc[nyc['Complaint Type']=='Derelict Vehicle']['resp_time_hrs'].dropna()

# %%
# since we want to find out if response time is different for various complaint types, we anova

# %%
#h0: avg_time_typ1=avg_time_typ2....avg_time_typ5
#ha: at least one is unequal

# %%
from scipy import stats

# %%
stats.f_oneway(type1,type2,type3,type4,type5)
# Out:
# F_onewayResult(statistic=2012.0389087633791, pvalue=0.0)

# %% [raw]
# as p <0.05 , we will reject the H0
# the compaint types have on an average the different response times

# %%
df_num=nyc.select_dtypes(include=np.number)

# %%
import statsmodels.formula.api as smf

# %%
# smf.ols(formula='resp_time_hrs=Latitude+Longitude',data=nyc)

# %%
df_num.describe()
# Out:
#          Unique Key   Incident Zip  X Coordinate (State Plane)  \
# count  3.645580e+05  361560.000000                3.605280e+05
# mean   3.106595e+07   10858.496659                1.005043e+06
# std    7.331531e+05     578.263114                2.196362e+04
# min    2.960737e+07      83.000000                9.133570e+05
# 25%    3.049938e+07   10314.000000                9.919460e+05
# 50%    3.108795e+07   11209.000000                1.003470e+06
# 75%    3.167433e+07   11238.000000                1.019134e+06
# max    3.231065e+07   11697.000000                1.067186e+06
#
#        Y Coordinate (State Plane)  School or Citywide Complaint  Vehicle Type  \
# count               360528.000000                           0.0           0.0
# mean                203425.305782                           NaN           NaN
# std                  29842.192857                           NaN           NaN
# min                 121185.000000                           NaN           NaN
# ...

# %%
df_num.columns
# Out:
# Index(['Unique Key', 'Incident Zip', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Garage Lot Name', 'Latitude', 'Longitude', 'resp_time',
#        'resp_time_hrs'],
#       dtype='object')

# %%
df_num.corr()
# Out:
#                               Unique Key  Incident Zip  \
# Unique Key                      1.000000     -0.008518
# Incident Zip                   -0.008518      1.000000
# X Coordinate (State Plane)     -0.018941      0.395480
# Y Coordinate (State Plane)     -0.004725     -0.489262
# School or Citywide Complaint         NaN           NaN
# Vehicle Type                         NaN           NaN
# Taxi Company Borough                 NaN           NaN
# Taxi Pick Up Location                NaN           NaN
# Garage Lot Name                      NaN           NaN
# Latitude                       -0.004710     -0.489519
# Longitude                      -0.018951      0.394825
# resp_time_hrs                   0.064800      0.054433
#
#                               X Coordinate (State Plane)  \
# Unique Key                                     -0.018941
# Incident Zip                                    0.395480
# X Coordinate (State Plane)                      1.000000
# ...

# %%
df_num.corr().shape
# Out:
# (12, 12)

# %%
df_num.corr().iloc[11,:]
# Out:
# Unique Key                      0.064800
# Incident Zip                    0.054433
# X Coordinate (State Plane)      0.105606
# Y Coordinate (State Plane)      0.027300
# School or Citywide Complaint         NaN
# Vehicle Type                         NaN
# Taxi Company Borough                 NaN
# Taxi Pick Up Location                NaN
# Garage Lot Name                      NaN
# Latitude                        0.027220
# Longitude                       0.105678
# resp_time_hrs                   1.000000
# Name: resp_time_hrs, dtype: float64

# %%
import seaborn as sns

# %%
sns.heatmap(df_num.corr(),cmap='viridis')
# Out:
# <AxesSubplot:>
